# %%
# !pip install ./algebra
# !pip install pyvista
# Out:
# Processing c:\users\roy.gonzalez\pycharmprojects\scientificproject\algebra
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for algebra: filename=algebra-0.1.6-py3-none-any.whl size=8888 sha256=586071ce8ff6f1205a67ba3b7bb8a62b3f9d1b5a6fb171958125262e1e43a208
#   Stored in directory: C:\Users\roy.gonzalez\AppData\Local\Temp\pip-ephem-wheel-cache-vxk5zztx\wheels\69\77\48\6c88e59aa2f3201f455a9d78ef80a6affd1564765d060f3c88
# Successfully built algebra
# ...
#   Attempting uninstall: algebra
#     Found existing installation: algebra 0.1.6
#     Uninstalling algebra-0.1.6:
#       Successfully uninstalled algebra-0.1.6
# ...

# %%
from plot.shape import Sphere, Cube, Point, Vector, Plane, Line, Polygon
from plot.viewer import Viewer

# %%
viewer = Viewer(notebook=True)
viewer.draw(Sphere())
viewer.run()
# Out:
# C:\Users\roy.gonzalez\PycharmProjects\scientificProject\.venv\Lib\site-packages\pyvista\jupyter\notebook.py:37: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
from algebra.euclidean import rotate_x

facet = [
    [0, 0, 0],  # Vertex 0
    [1, 0, 0],  # Vertex 1
    [1, 1, 0],  # Vertex 2
    [0, 1, 0]  # Vertex 3
]


viewer = Viewer(notebook=True)
viewer.draw(Polygon(facet))


x_facet = [ rotate_x(face, 90) for face in facet]

viewer.draw(Polygon(x_facet))
viewer.run()
# Out:
# C:\Users\roy.gonzalez\PycharmProjects\scientificProject\.venv\Lib\site-packages\pyvista\core\utilities\points.py:55: UserWarning: Points is not a float type. This can cause issues when transforming or applying filters. Casting to ``np.float32``. Disable this by passing ``force_float=False``.
#   warnings.warn(
# C:\Users\roy.gonzalez\PycharmProjects\scientificProject\.venv\Lib\site-packages\pyvista\jupyter\notebook.py:37: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
